# %% [markdown]
# <a href="https://colab.research.google.com/github/ob1knb/phd-thesis/blob/master/Burke_Code_3_components_%26_Time_Shift_July_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Dataset Assembly**

# %% [markdown]
# Dataset 1: Meltwater Dataset

# %%
# !pip install seaborn
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')
from ast import increment_lineno
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
#stats = pd.read_csv('/content/Walt_Disney Oct 27-Dec 21, 2023 .csv')
#stats = pd.read_csv('/content/DisneyFinal2.csv')
stats = pd.read_csv('/content/DisneyFinal3.csv')
#first row as header:
#stats.columns = stats.iloc[0]
#stats = stats[1:]

# %%
stats.head()
# Out:
#         Date Headline                                                URL  \
# 0  7/22/2022      NaN  http://twitter.com/shongables/statuses/1550632...
# 1  7/22/2022      NaN  http://twitter.com/PrincessAzilem/statuses/155...
# 2  7/22/2022      NaN  http://twitter.com/MyRealtorJoshF/statuses/155...
# 3  7/22/2022      NaN  http://twitter.com/justincreates/statuses/1550...
# 4  7/22/2022      NaN  http://twitter.com/marialugo351/statuses/15506...
#
#   Opening Text                                       Hit Sentence   Source  \
# 0          NaN  FLORIDA: Magic Kingdom not so magical after a ...  Twitter
# 1          NaN  This Raccoonda needs a mega pint of wine. It w...  Twitter
# 2          NaN  Would you rather spend five days exploring Dis...  Twitter
# 3          NaN  Marvel Studios has reportedly trademarked the ...  Twitter
# 4          NaN  So good I had to share! Check out all the item...  Twitter
#
#         Influencer        Country Subregion Language  ... Editorial Echo  \
# 0      @shongables  United States       NaN  English  ...            NaN
# 1  @PrincessAzilem  United States       NaN  English  ...            NaN
# 2  @MyRealtorJoshF  United States       NaN  English  ...            NaN
# 3   @justincreates  United States       NaN  English  ...            NaN
# 4    @marialugo351  United States       NaN  English  ...            NaN
#
#   Views Likes Replies Retweets Comments Shares Reactions Threads Is Verified
# 0   NaN  13.0     8.0      NaN      NaN   13.0      13.0     8.0        True
# 1   NaN   1.0     0.0      NaN      NaN    3.0       1.0     0.0       False
# 2   NaN   NaN     NaN      NaN      NaN    NaN       NaN     NaN       False
# 3   NaN   0.0     0.0      NaN      NaN    1.0       0.0     0.0       False
# 4   NaN   NaN     NaN      NaN      NaN    NaN       NaN     NaN       False
#
# [5 rows x 47 columns]

# %%
len(stats)
# Out:
# 136064

# %%
stats.columns
# Out:
# Index(['Date', 'Headline', 'URL', 'Opening Text', 'Hit Sentence', 'Source',
#        'Influencer', 'Country', 'Subregion', 'Language', 'Reach',
#        'Desktop Reach', 'Mobile Reach', 'Twitter Social Echo',
#        'Facebook Social Echo', 'Reddit Social Echo', 'National Viewership',
#        'Engagement', 'AVE', 'Sentiment', 'Key Phrases', 'Input Name',
#        'Keywords', 'Twitter Authority', 'Tweet Id', 'Twitter Id',
#        'Twitter Client', 'Twitter Screen Name', 'User Profile Url',
#        'Twitter Bio', 'Twitter Followers', 'Twitter Following',
#        'Alternate Date Format', 'Time', 'State', 'City', 'Social Echo Total',
#        'Editorial Echo', 'Views', 'Likes', 'Replies', 'Retweets', 'Comments',
#        'Shares', 'Reactions', 'Threads', 'Is Verified'],
#       dtype='object')

# %%
#removing empty Columns
#stats = stats[['Hit Sentence', 'Influencer', 'Reach',
      # 'Engagement', 'AVE',
      # 'Twitter Authority',
      # 'Twitter Followers', 'Twitter Following',
      # 'Alternate Date Format', 'Views', 'Likes', 'Replies', 'Retweets',
      # 'Shares', 'Reactions', 'Threads']]

# %%
#removing empty Columns (removing columns with lots of nulls)
stats = stats[['Hit Sentence', 'Influencer', 'Reach',
       'AVE',
       'Twitter Authority',
       'Twitter Followers', 'Twitter Following',
       'Alternate Date Format']]

# %%
#Renaming the columns with single-word syntax
#stats.columns = ['HitSentence', 'Influencer', 'Reach',
     #  'Engagement', 'AVE',
     #  'TwitterAuthority',
     #  'TwitterFollowers', 'TwitterFollowing',
     #  'Date', 'Views', 'Likes', 'Replies', 'Retweets',
     #  'Shares', 'Reactions', 'Threads']

# %%
#Renaming the columns with single-word syntax (removing columns with lots of nulls)
stats.columns = ['HitSentence', 'Influencer', 'Reach',
       'AVE',
       'TwitterAuthority',
       'TwitterFollowers', 'TwitterFollowing',
       'Date']

# %%
stats.columns
# Out:
# Index(['HitSentence', 'Influencer', 'Reach', 'AVE', 'TwitterAuthority',
#        'TwitterFollowers', 'TwitterFollowing', 'Date'],
#       dtype='object')

# %%
#Replace NAs in column:
#stats['Engagement'] = stats['Engagement'].fillna(0)
#stats['Shares'] = stats['Shares'].fillna(0)
#stats['Reactions'] = stats['Reactions'].fillna(0)
#stats['Threads'] = stats['Threads'].fillna(0)
#stats['Views'] = stats['Views'].fillna(0)
#stats['Likes'] = stats['Likes'].fillna(0)
#stats['Replies'] = stats['Replies'].fillna(0)
#stats['Retweets'] = stats['Retweets'].fillna(0)
#stats['TwitterFollowing'] = stats['TwitterFollowing'].fillna(0)
#stats['TwitterFollowers'] = stats['TwitterFollowers'].fillna(0)
#stats['TwitterAuthority'] = stats['TwitterAuthority'].fillna(0)
#stats['Reach'] = stats['Reach'].fillna(0)

#alternate:
#stats['Engagement'] = stats['Engagement'].replace(np.nan, 0)
#stats['Shares'] = stats['Shares'].replace(np.nan, 0)
#stats['Reactions'] = stats['Reactions'].replace(np.nan, 0)
#stats['Threads'] = stats['Threads'].replace(np.nan, 0)
#stats['Views'] = stats['Views'].replace(np.nan, 0)
#stats['Likes'] = stats['Likes'].replace(np.nan, 0)
#stats['Replies'] = stats['Replies'].replace(np.nan, 0)
#stats['Retweets'] = stats['Retweets'].replace(np.nan, 0)
#stats['TwitterFollowing'] = stats['TwitterFollowing'].replace(np.nan, 0)
#stats['TwitterFollowers'] = stats['TwitterFollowers'].replace(np.nan, 0)
#stats['TwitterFollowers'] = stats['TwitterFollowers'].replace(np.nan, 0)
#stats['TwitterAuthority'] = stats['TwitterAuthority'].replace(np.nan, 0)
#stats['Reach'] = stats['Reach'].replace(np.nan, 0)

# %%
#Replace NAs in column (with columns with high numbers of Nulls removed):

stats['TwitterFollowing'] = stats['TwitterFollowing'].fillna(0)
stats['TwitterFollowers'] = stats['TwitterFollowers'].fillna(0)
stats['TwitterAuthority'] = stats['TwitterAuthority'].fillna(0)
stats['Reach'] = stats['Reach'].fillna(0)

#alternate:

stats['TwitterFollowing'] = stats['TwitterFollowing'].replace(np.nan, 0)
stats['TwitterFollowers'] = stats['TwitterFollowers'].replace(np.nan, 0)
stats['TwitterFollowers'] = stats['TwitterFollowers'].replace(np.nan, 0)
stats['TwitterAuthority'] = stats['TwitterAuthority'].replace(np.nan, 0)
stats['Reach'] = stats['Reach'].replace(np.nan, 0)

# %% [markdown]
# NOTE: consider whether we keep the observations where they have no followers.

# %%
#Only slightly more than 100 NAs are left out of 117K observations, so the decision is made to drop them
stats = stats.dropna()
stats = stats.reset_index(drop=True)

# %%
stats.tail(5)
# Out:
#                                               HitSentence      Influencer  \
# 135882  Today marks the 63rd anniversaries of Walt Dis...   @arenstenslie
# 135883  I held out as long as I could. I cancelled Dis...      @bopper416
# 135884  Beep. Bop. Boop. #TheAcolyte #Acolyte #StarWar...  @azredscorpion
# 135885  A couple of sweet potatoes~! #WIP #TheOwlHouse...     @cupidmanna
# 135886  #TheAcolyte #Acolyte #StarWars #Disney #Disney...  @azredscorpion
#
#          Reach   AVE TwitterAuthority TwitterFollowers TwitterFollowing  \
# 135882  1773.0  16.4              6.0           1773.0            231.0
# 135883   387.0  3.58              5.0            387.0            552.0
# 135884   300.0  2.77              5.0            300.0             83.0
# 135885    10.0  0.09              1.0             10.0             37.0
# 135886   300.0  2.77              5.0            300.0             83.0
#
#              Date
# 135882  6/21/2024
# 135883  6/21/2024
# 135884  6/21/2024
# 135885  6/21/2024
# 135886  6/21/2024

# %%
#stats[0:10][["HitSentence"]]

# %%
#Adding colums for derived variables
stats['Alignment'] = range(len(stats))
stats['VaderSentiment'] = range(len(stats))
stats.head()
# Out:
#                                          HitSentence       Influencer   Reach  \
# 0  FLORIDA: Magic Kingdom not so magical after a ...      @shongables  6569.0
# 1  This Raccoonda needs a mega pint of wine. It w...  @PrincessAzilem    85.0
# 2  Would you rather spend five days exploring Dis...  @MyRealtorJoshF       0
# 3  Marvel Studios has reportedly trademarked the ...   @justincreates   200.0
# 4  So good I had to share! Check out all the item...    @marialugo351    11.0
#
#      AVE TwitterAuthority TwitterFollowers TwitterFollowing       Date  \
# 0  60.76              8.0           6569.0           1446.0  7/22/2022
# 1   0.79              3.0             85.0            385.0  7/22/2022
# 2    0.0              1.0                0              1.0  7/22/2022
# 3   1.85              4.0            200.0            890.0  7/22/2022
# 4    0.1              2.0             11.0             22.0  7/22/2022
#
#    Alignment  VaderSentiment
# 0          0               0
# 1          1               1
# 2          2               2
# 3          3               3
# 4          4               4

# %%
#stats.Alignment = stats.Alignment.astype('category')
#stats.VaderSentiment = stats.VaderSentiment.astype('category')
#stats.head()

# %%
#stats[['Reach', 'Engagement', 'Views', 'Likes', 'Replies', 'Retweets', 'Shares',\
       #'Reactions', 'Threads', 'AVE']] = stats[['Reach', 'Engagement', 'Views', 'Likes',\
                                               # 'Replies', 'Retweets', 'Shares', 'Reactions', \
                                               # 'Threads', 'AVE']].apply(pd.to_numeric)

# %%
stats['Date'].isnull().sum()
# Out:
# 0

# %%
stats['Date'] = pd.to_datetime(stats['Date'], errors='coerce')
#stats[['Date']] = stats[['Date']].apply(pd.to_datetime)
#stats['Date'] = pd.to_datetime(stats['Date'], format="mixed")

# %%
stats['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
stats.head()
# Out:
#                                          HitSentence       Influencer   Reach  \
# 0  FLORIDA: Magic Kingdom not so magical after a ...      @shongables  6569.0
# 1  This Raccoonda needs a mega pint of wine. It w...  @PrincessAzilem    85.0
# 2  Would you rather spend five days exploring Dis...  @MyRealtorJoshF       0
# 3  Marvel Studios has reportedly trademarked the ...   @justincreates   200.0
# 4  So good I had to share! Check out all the item...    @marialugo351    11.0
#
#      AVE TwitterAuthority TwitterFollowers TwitterFollowing       Date  \
# 0  60.76              8.0           6569.0           1446.0 2022-07-22
# 1   0.79              3.0             85.0            385.0 2022-07-22
# 2    0.0              1.0                0              1.0 2022-07-22
# 3   1.85              4.0            200.0            890.0 2022-07-22
# 4    0.1              2.0             11.0             22.0 2022-07-22
#
#    Alignment  VaderSentiment
# 0          0               0
# 1          1               1
# 2          2               2
# 3          3               3
# 4          4               4

# %% [markdown]
# Secondary dataset: Stock Market Data
#
#
# *   (Standalone dataset with two variables: stock price and timestamp)

# %% [markdown]
# https://www.marketwatch.com/investing/stock/dis/download-data?startDate=7/22/2022&endDate=12/21/2023

# %%
#stock = pd.read_csv('/content/stock_price2.csv')
stock = pd.read_csv('/content/stock_price3.csv')

# %%
stock[['Date']] = stock[['Date']].apply(pd.to_datetime)

# %%
stock['Volume'] = stock.iloc[:, 5].str.replace(',', '').astype(int)

# %%
stock.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2024-06-20  100.57  101.94  100.38  101.84   7886934
# 1 2024-06-18  101.12  101.76  100.61  101.50   7044674
# 2 2024-06-17  100.98  101.92  100.62  101.52  10388990
# 3 2024-06-14   99.81  100.38   99.25   99.97   7087573
# 4 2024-06-13  100.61  101.07   99.61  100.09  10164570

# %%
stock.tail()
# Out:
#           Date   Open   High    Low  Close    Volume
# 486 2022-07-13  92.12  93.25  91.01  92.94  12006430
# 487 2022-07-12  93.58  95.25  93.31  93.60   8665299
# 488 2022-07-11  95.00  95.34  93.43  93.64   7650632
# 489 2022-07-08  96.57  97.12  95.35  95.86   7717297
# 490 2022-07-07  96.90  97.53  95.93  97.43   7813050

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    491 non-null    datetime64[ns]
#  1   Open    491 non-null    float64
#  2   High    491 non-null    float64
#  3   Low     491 non-null    float64
#  4   Close   491 non-null    float64
#  5   Volume  491 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 23.1 KB

# %% [markdown]
# # **Data Prep/Feature Engineering**
# Vader Sentiment Analysis

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.7.4)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Extract the column containing text data
HitSentence = stats['HitSentence']

# Analyze sentiment for each text in the column
sentiment_scores = [analyzer.polarity_scores(text) for text in HitSentence]

# Add the sentiment scores to the DataFrame
stats['VaderSentiment'] = [score['compound'] for score in sentiment_scores]

# Show the DataFrame with sentiment scores
stats.VaderSentiment.head()
# Out:
# 0   -0.5627
# 1    0.2023
# 2    0.0000
# 3   -0.2023
# 4    0.8620
# Name: VaderSentiment, dtype: float64

# %%
#Put an interval around Zero that makes sense, based on binning
#Setting the "Alignment" variable as binary based on Vader Sentiment Score
for i in range(len(stats)):
  if stats.VaderSentiment[i] <= -.25:
    stats.Alignment[i] = -1
  elif stats.VaderSentiment[i] > -.25 and stats.VaderSentiment[i] <= .25:
    stats.Alignment[i] = 0
  else:
    stats.Alignment[i] = 1

# %%
stats.head()
# Out:
#                                          HitSentence       Influencer   Reach  \
# 0  FLORIDA: Magic Kingdom not so magical after a ...      @shongables  6569.0
# 1  This Raccoonda needs a mega pint of wine. It w...  @PrincessAzilem    85.0
# 2  Would you rather spend five days exploring Dis...  @MyRealtorJoshF       0
# 3  Marvel Studios has reportedly trademarked the ...   @justincreates   200.0
# 4  So good I had to share! Check out all the item...    @marialugo351    11.0
#
#      AVE TwitterAuthority TwitterFollowers TwitterFollowing       Date  \
# 0  60.76              8.0           6569.0           1446.0 2022-07-22
# 1   0.79              3.0             85.0            385.0 2022-07-22
# 2    0.0              1.0                0              1.0 2022-07-22
# 3   1.85              4.0            200.0            890.0 2022-07-22
# 4    0.1              2.0             11.0             22.0 2022-07-22
#
#    Alignment  VaderSentiment
# 0         -1         -0.5627
# 1          0          0.2023
# 2          0          0.0000
# 3          0         -0.2023
# 4          1          0.8620

# %%
stats['Reach'] = pd.to_numeric(stats['Reach'], errors='coerce')
stats['AVE'] = pd.to_numeric(stats['AVE'], errors='coerce')
stats['TwitterAuthority'] = pd.to_numeric(stats['TwitterAuthority'], errors='coerce')
stats['TwitterFollowers'] = pd.to_numeric(stats['TwitterFollowers'], errors='coerce')
stats['TwitterFollowing'] = pd.to_numeric(stats['TwitterFollowing'], errors='coerce')
stats['Alignment'] = pd.to_numeric(stats['Alignment'], errors='coerce')
stats['VaderSentiment'] = pd.to_numeric(stats['VaderSentiment'], errors='coerce')

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
#  **Dataset 1: Data Understanding**

# %% [markdown]
# Identify Key Variables

# %% [markdown]
# Key Variables Summary Statistics

# %%
#Descriptive statistics
stats.describe()
# Out:
#               Reach            AVE  TwitterAuthority  TwitterFollowers  \
# count  1.358860e+05  135869.000000     135886.000000      1.358860e+05
# mean   4.529061e+03      40.711052          4.519700      4.529061e+03
# min    0.000000e+00       0.000000          0.000000      0.000000e+00
# 25%    7.700000e+01       0.710000          3.000000      7.700000e+01
# 50%    3.860000e+02       3.570000          5.000000      3.860000e+02
# 75%    1.409000e+03      13.020000          6.000000      1.409000e+03
# max    1.468304e+07  135818.170000         10.000000      1.468304e+07
# std    7.341002e+04     652.317022          2.052866      7.341002e+04
#
#        TwitterFollowing                           Date      Alignment  \
# count     135886.000000                         135886  135887.000000
# mean        1964.884160  2023-04-21 06:26:01.273420288       0.467962
# min            0.000000            2022-07-22 00:00:00      -1.000000
# 25%          143.000000            2022-10-30 00:00:00       0.000000
# 50%          542.000000            2023-03-24 00:00:00       1.000000
# 75%         1938.000000            2023-09-26 00:00:00       1.000000
# max       455728.000000            2024-06-21 00:00:00       1.000000
# std         8106.594026                            NaN       0.680577
#
#        VaderSentiment
# count   135887.000000
# mean         0.345399
# min         -0.995600
# 25%          0.000000
# 50%          0.440400
# 75%          0.802000
# max          0.999900
# std          0.474052

# %% [markdown]
# Data Visualization

# %%
#Reach Histogram
Reach_Hist = sns.distplot(stats.Reach)

# %%
#Reach Boxplot
Reach_Boxplot = sns.boxplot(stats.Reach)

# %%
#AVE Histogram
AVE_Hist = sns.distplot(stats.AVE)

# %%
#AVE Boxplot
AVE_Boxplot = sns.boxplot(stats.AVE)

# %%
#TwitterAuthority Histogram
TwitterAuthority_Hist = sns.distplot(stats.TwitterAuthority)

# %%
#TwitterAuthority Boxplot
TwitterAuthority_Boxplot = sns.boxplot(stats.TwitterAuthority)

# %%
#TwitterFollowers Histogram
TwitterFollowers_Hist = sns.distplot(stats.TwitterFollowers)

# %%
#TwitterFollowers Boxplot
TwitterFollowers_Boxplot = sns.boxplot(stats.TwitterFollowers)

# %%
#TwitterFollowing Histogram
TwitterFollowing_Hist = sns.distplot(stats.TwitterFollowing)

# %%
#TwitterFollowing Boxplot
TwitterFollowing_Boxplot = sns.boxplot(stats.TwitterFollowing)

# %%
#Views Histogram
#Views_Hist = sns.distplot(stats.Views)

# %%
#Views Boxplot
#Views_Boxplot = sns.boxplot(stats.Views)

# %%
#Engagement Boxplot
#Engagement_Boxplot = sns.boxplot(stats.Engagement)

# %%
#Engagement Histogram
#Engagement_Hist = sns.distplot(stats.Engagement)

# %%
#Likes Histogram
#Likes_Hist = sns.distplot(stats.Likes)

# %%
#Likes Boxplot
#Likes_Boxplot = sns.boxplot(stats.Likes)

# %%
#Replies Histogram
#Replies_Hist = sns.distplot(stats.Replies)

# %%
#Replies Boxplot
#Replies_Boxplot = sns.boxplot(stats.Replies)

# %%
#Retweets Histogram
#Retweets_Hist = sns.distplot(stats.Retweets)

# %%
#Retweets Boxplot
#Retweets_Boxplot = sns.boxplot(stats.Retweets)

# %%
#Shares Histogram
#Shares_Hist = sns.distplot(stats.Shares)

# %%
#Shares Boxplot
#Shares_Boxplot = sns.boxplot(stats.Shares)

# %%
#Reactions Histogram
#Reactions_Hist = sns.distplot(stats.Reactions)

# %%
#Reactions Boxplot
#Reactions_Boxplot = sns.boxplot(stats.Reactions)

# %%
#Threads Histogram
#Threads_Hist = sns.distplot(stats.Threads)

# %%
#Threads Boxplot
#Threads_Boxplot = sns.boxplot(stats.Threads)

# %%
#Alignment Histogram
Alignment_Hist = sns.distplot(stats.Alignment)

# %%
#Alignment Boxplot
Alignment_Boxplot = sns.boxplot(stats.Alignment)

# %%
#VaderSentiment Histogram
VaderSentiment_Hist = sns.distplot(stats.VaderSentiment)
#idetify if there are clear paths so we can do bins, justified by the visualization
#support bin strategy in findings section of dissertation
#Kmeans could be an additional step to categorize this.
#Look into 7 level Vader sentiment
#Pay attention to the large group close to zero

# %%
#VaderSentiment Boxplot
VaderSentiment_Boxplot = sns.boxplot(stats.VaderSentiment)

# %% [markdown]
# **Dataset 2 (Stock Price): Data Understanding**

# %% [markdown]
# Key Variable Summary Statistics

# %%
stock.describe()
# Out:
#                                 Date        Open        High         Low  \
# count                            491  491.000000  491.000000  491.000000
# mean   2023-06-27 09:23:05.743380992   97.890204   98.956864   96.828513
# min              2022-07-07 00:00:00   79.100000   79.790000   78.730000
# 25%              2022-12-29 12:00:00   90.115000   91.030000   89.400000
# 50%              2023-06-28 00:00:00   96.520000   97.780000   95.430000
# 75%              2023-12-20 12:00:00  104.995000  106.350000  103.870000
# max              2024-06-20 00:00:00  124.730000  126.480000  123.450000
# std                              NaN   10.328561   10.496465   10.196025
#
#             Close        Volume
# count  491.000000  4.910000e+02
# mean    97.916273  1.259908e+07
# min     79.320000  5.426053e+06
# 25%     90.340000  8.622921e+06
# 50%     96.640000  1.091533e+07
# 75%    105.370000  1.378024e+07
# max    124.960000  7.027352e+07
# std     10.368918  7.646377e+06

# %% [markdown]
# Key Variable Visualizations

# %%
#Biggest effect of media/news will likely be on the opening price
Open_Hist = sns.distplot(stock.Open)

# %%
Open_Box = sns.boxplot(stock.Open)

# %%
High_Dist = sns.distplot(stock.High)

# %%
High_Box = sns.boxplot(stock.High)

# %%
Low_Dist = sns.distplot(stock.Low)

# %%
Low_Box = sns.boxplot(stock.Low)

# %%
Close_Dist = sns.distplot(stock.Close)

# %%
Close_Box = sns.boxplot(stock.Close)

# %%
#Very important
Volume_Dist = sns.distplot(stock.Volume)

# %%
Volume_Box = sns.boxplot(stock.Volume)

# %% [markdown]
# ## **Preliminary EDA**

# %% [markdown]
# **Dataset 1 (Meltwater)**

# %% [markdown]
# Detect and Address Outliers

# %%
#Outier detector function (counts outliers)
def outlier_detector(column):
  outliers = 0
  Q1 = np.percentile(column, 25)
  Q3 = np.percentile(column, 75)
  IQR = Q3-Q1
  Outlier_Min = Q3 + 1.5*IQR
  max = np.max(column)
  for i in range(len(column)):
    if column[i] >= Q3 + 1.5*IQR:
      outliers += 1
  print("Q1 is " + str(Q1))
  print("Q3 is " + str(Q3))
  print("Outliers range from " + str(Outlier_Min) + " to " + str(max))
  print("number of outliers is " + str(outliers))

# %%
#MUST RUN THIS (or data will disappear)
stats = stats.dropna()
stats = stats.reset_index(drop=True)

# %%
outlier_detector(stats.TwitterFollowing)
# Out:
# Q1 is 143.0
# Q3 is 1938.0
# Outliers range from 4630.5 to 455728.0
# number of outliers is 13267

# %%
#Outlier remover (FUNCTION NEEDS TWEAKING)
#def outlier_remover(data, column):
  #Q1 = np.percentile(column, 25)
  #Q3 = np.percentile(column, 75)
  #IQR = Q3-Q1
  #print(IQR)
  #data = data[column < (Q3 + 1.5*IQR)]
  #data = data.reset_index(drop=True)
  #data = pd.DataFrame(data)
  #print(IQR)

# %%
#Removing outliers from all remaining variables
Q1 = np.percentile(stats.Reach, 25)
Q3 = np.percentile(stats.Reach, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['Reach'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)

Q1 = np.percentile(stats.AVE, 25)
Q3 = np.percentile(stats.AVE, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['AVE'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)


Q1 = np.percentile(stats.TwitterAuthority, 25)
Q3 = np.percentile(stats.TwitterAuthority, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['TwitterAuthority'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)

Q1 = np.percentile(stats.TwitterFollowers, 25)
Q3 = np.percentile(stats.TwitterFollowers, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['TwitterFollowers'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)

Q1 = np.percentile(stats.TwitterFollowing, 25)
Q3 = np.percentile(stats.TwitterFollowing, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['TwitterFollowing'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)

Q1 = np.percentile(stats.Alignment, 25)
Q3 = np.percentile(stats.Alignment, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['Alignment'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)

Q1 = np.percentile(stats.VaderSentiment, 25)
Q3 = np.percentile(stats.VaderSentiment, 75)
IQR = Q3-Q1
print(IQR)
stats = stats[stats['VaderSentiment'] < (Q3 + 1.5*IQR)]
stats = stats.reset_index(drop=True)
stats = pd.DataFrame(stats)
# Out:
# 1331.0
# 7.35
# 2.0
# 658.0
# 1052.0
# 1.0
# 0.8247249999999999

# %%
def min_max(column):
  min = np.min(column)
  max = np.max(column)
  print("min is " + str(min))
  print("max is " + str(max))

# %%
min_max(stats.TwitterFollowing)
# Out:
# min is 0.0
# max is 2724.0

# %%
stats = stats.dropna()
stats = stats.reset_index(drop=True)

# %%
stats.head(5)
# Out:
#                                          HitSentence       Influencer  Reach  \
# 0  This Raccoonda needs a mega pint of wine. It w...  @PrincessAzilem   85.0
# 1  Would you rather spend five days exploring Dis...  @MyRealtorJoshF    0.0
# 2  Marvel Studios has reportedly trademarked the ...   @justincreates  200.0
# 3  So good I had to share! Check out all the item...    @marialugo351   11.0
# 4  So good I had to share! Check out all the item...      @BriansPosh  429.0
#
#     AVE  TwitterAuthority  TwitterFollowers  TwitterFollowing       Date  \
# 0  0.79               3.0              85.0             385.0 2022-07-22
# 1  0.00               1.0               0.0               1.0 2022-07-22
# 2  1.85               4.0             200.0             890.0 2022-07-22
# 3  0.10               2.0              11.0              22.0 2022-07-22
# 4  3.97               5.0             429.0             941.0 2022-07-22
#
#    Alignment  VaderSentiment
# 0          0          0.2023
# 1          0          0.0000
# 2          0         -0.2023
# 3          1          0.8620
# 4          1          0.8620

# %%
outlier_detector(stats.AVE)
# Out:
# Q1 is 0.44
# Q3 is 5.2
# Outliers range from 12.34 to 15.73
# number of outliers is 5891

# %%
outlier_detector(stats.Reach)
# Out:
# Q1 is 48.0
# Q3 is 562.0
# Outliers range from 1333.0 to 1701.0
# number of outliers is 5897

# %%
outlier_detector(stats.TwitterAuthority)
# Out:
# Q1 is 3.0
# Q3 is 5.0
# Outliers range from 8.0 to 6.0
# number of outliers is 0

# %%
outlier_detector(stats.TwitterFollowers)
# Out:
# Q1 is 48.0
# Q3 is 562.0
# Outliers range from 1333.0 to 1701.0
# number of outliers is 5897

# %%
outlier_detector(stats.TwitterFollowing)
# Out:
# Q1 is 83.0
# Q3 is 855.0
# Outliers range from 2013.0 to 2724.0
# number of outliers is 6697

# %% [markdown]
# **Dataset 2 (Stock Prices)**

# %% [markdown]
# Detect and address outliers

# %%
outlier_detector(stock.Open)
# Out:
# Q1 is 90.11500000000001
# Q3 is 104.995
# Outliers range from 127.315 to 124.73
# number of outliers is 0

# %%
outlier_detector(stock.Volume)
# Out:
# Q1 is 8622921.0
# Q3 is 13780240.0
# Outliers range from 21516218.5 to 70273516
# number of outliers is 35

# %% [markdown]
# ### ***Assembly of Derived Dataset ***

# %%
# Generate sample time series data

#date_rng = pd.date_range(start='2022-07-22', end='2024-04-30', freq='D')--USE FOR OLD DATE RANGE
date_rng = pd.date_range(start='2022-07-22', end='2024-06-21', freq='D')
data = {'date': date_rng}
stats_derived = pd.DataFrame(data)

# Set the 'date' column as the index
stats_derived.set_index('date', inplace=True)

# %%
stats_derived.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2024-06-17 00:00:00, 2024-06-18 00:00:00, 2024-06-19 00:00:00, 2024-06-20 00:00:00, 2024-06-21 00:00:00]

# %% [markdown]
# **Metrics Consolidated Into Time Series**

# %% [markdown]
# Self Congruence derived from ‘VaderSentiment’

# %%
Self_Congruence = stats.groupby(stats["Date"])["VaderSentiment"].mean()
stats_derived['Self_Congruence'] = Self_Congruence
Self_Congruence.head()
# Out:
# Date
# 2022-07-22    0.475651
# 2022-07-23    0.446156
# 2022-07-24    0.431740
# 2022-07-25    0.425161
# 2022-07-26    0.435984
# Name: VaderSentiment, dtype: float64

# %% [markdown]
# Brand Loyalty Derived from Alignment
#
# > positive_posts_day/posters_day

# %%
stats_alignment = stats["Alignment"]
stats_alignment[stats_alignment<0] = 0
stats_alignment = stats_alignment.to_frame()
stats2 = stats
stats2["Alignment"] = stats_alignment['Alignment']
Number_positive_posts = stats2.groupby(stats2["Date"])["Alignment"].sum()
Number_positive_posts
# Out:
# Date
# 2022-07-22     37
# 2022-07-23    110
# 2022-07-24     97
# 2022-07-25    112
# 2022-07-26    115
#              ...
# 2024-06-17     19
# 2024-06-18     39
# 2024-06-19     44
# 2024-06-20     38
# 2024-06-21     22
# Name: Alignment, Length: 700, dtype: int64

# %%
#number of posters per day
number_poster_per_day = stats2.groupby(stats2["Date"])["Influencer"].unique()
number_poster_per_day
# Out:
# Date
# 2022-07-22    [@PrincessAzilem, @MyRealtorJoshF, @justincrea...
# 2022-07-23    [@Yes_RyanTTV, @cestlavieMSR, @ENOC_21, @espla...
# 2022-07-24    [@MikeH46123995, @AndyJimVlogs, @Umesh_Tharuka...
# 2022-07-25    [@taycholee, @bucknut1978, @CutieJP, @RitaDarl...
# 2022-07-26    [@Guills, @SugarPalace, @spavlenko7, @amydrz, ...
#                                     ...
# 2024-06-17    [@lockwoodco_vfan, @chrisebbert19, @llr_theres...
# 2024-06-18    [@cameronclapp, @lockwoodco_vfan, @davidjhemph...
# 2024-06-19    [@azredscorpion, @disneyfan9523, @fausto316, @...
# 2024-06-20    [@jammiedior, @azredscorpion, @mikeyjayraymond...
# 2024-06-21    [@christy_rose1, @2talltom, @azredscorpion, @r...
# Name: Influencer, Length: 700, dtype: object

# %%
for i in range(len(number_poster_per_day)):
  number_poster_per_day[i] = len(number_poster_per_day[i])

# %%
number_poster_per_day
# Out:
# Date
# 2022-07-22     50
# 2022-07-23    151
# 2022-07-24    136
# 2022-07-25    160
# 2022-07-26    159
#              ...
# 2024-06-17     40
# 2024-06-18     70
# 2024-06-19     64
# 2024-06-20     74
# 2024-06-21     45
# Name: Influencer, Length: 700, dtype: object

# %%
BrandLoyalty = number_poster_per_day
# Ensure both Series have the same length by dropping the last element of BrandLoyalty
BrandLoyalty = BrandLoyalty.iloc[:-1]
for i in range(len(BrandLoyalty)):
  BrandLoyalty[i] = Number_positive_posts[i]/BrandLoyalty[i]
#print(BrandLoyalty)

# %%
stats_derived['BrandLoyalty'] = BrandLoyalty
stats_derived.shape
# Out:
# (701, 2)

# %%
#NEEDS TO BE REWORKED
#based on the frequency of positive posting on that brand per user

#BrandLoyalty = stats.groupby(stats["Date"])["Alignment"].mean()
#stats_derived['BrandLoyalty'] = BrandLoyalty
#BrandLoyalty.head()

# %% [markdown]
# Brand Equity Derived from Sentiment
# Average_vader_sentiment/users_per_day

# %%
BrandEquity = [0] * len(Self_Congruence)
for i in range(len(Self_Congruence)):
  BrandEquity[i] = Self_Congruence[i]/(number_poster_per_day[i]+.01)
BrandEquity.append(0)
stats_derived['BrandEquity'] = BrandEquity

# %%
#NEEDS TO BE REWORKED
#calculated using average VADER sentiment score for  brand-focused posts
  #per user per time period (determined by the LSTM timesteps)

#BrandEquity = stats.groupby(stats["Date"])["VaderSentiment"].mean()
#stats_derived['BrandEquity'] = BrandEquity
#BrandEquity.head()

# %% [markdown]
# Aggregated (per day) metrics for engagement (post, likes, etc.)

# %%
Reach = stats.groupby(stats["Date"])["Reach"].mean()
stats_derived['Reach'] = Reach
Reach.head()
# Out:
# Date
# 2022-07-22    343.113208
# 2022-07-23    365.377907
# 2022-07-24    329.198718
# 2022-07-25    348.558659
# 2022-07-26    336.728814
# Name: Reach, dtype: float64

# %%
AVE = stats.groupby(stats["Date"])["AVE"].mean()
stats_derived['AVE'] = AVE
AVE.head()
# Out:
# Date
# 2022-07-22    3.173962
# 2022-07-23    3.380058
# 2022-07-24    3.044872
# 2022-07-25    3.224078
# 2022-07-26    3.114802
# Name: AVE, dtype: float64

# %%
TwitterAuthority = stats.groupby(stats["Date"])["TwitterAuthority"].mean()
stats_derived['TwitterAuthority'] = TwitterAuthority
TwitterAuthority.head()
# Out:
# Date
# 2022-07-22    3.735849
# 2022-07-23    3.837209
# 2022-07-24    3.724359
# 2022-07-25    3.770950
# 2022-07-26    3.644068
# Name: TwitterAuthority, dtype: float64

# %%
TwitterFollowers = stats.groupby(stats["Date"])["TwitterFollowers"].mean()
stats_derived['TwitterFollowers'] = TwitterFollowers
TwitterFollowers.head()
# Out:
# Date
# 2022-07-22    343.113208
# 2022-07-23    365.377907
# 2022-07-24    329.198718
# 2022-07-25    348.558659
# 2022-07-26    336.728814
# Name: TwitterFollowers, dtype: float64

# %%
TwitterFollowing = stats.groupby(stats["Date"])["TwitterFollowing"].mean()
stats_derived['TwitterFollowing'] = TwitterFollowing
TwitterFollowing.head()
# Out:
# Date
# 2022-07-22    539.490566
# 2022-07-23    596.186047
# 2022-07-24    506.788462
# 2022-07-25    543.910615
# 2022-07-26    545.960452
# Name: TwitterFollowing, dtype: float64

# %%
#Engagement = stats.groupby(stats["Date"])["Engagement"].mean()
#stats_derived['Engagement'] = Engagement
#Engagement.head()

# %%
#Views = stats.groupby(stats["Date"])["Views"].mean()
#stats_derived['Views'] = Views
#Views.head()

# %%
#Likes = stats.groupby(stats["Date"])["Likes"].mean()
#stats_derived['Likes'] = Likes
#Likes.head()

# %%
#Replies = stats.groupby(stats["Date"])["Replies"].mean()
#stats_derived['Replies'] = Replies
#Replies.head()

# %%
#Retweets = stats.groupby(stats["Date"])["Retweets"].mean()
#stats_derived['Retweets'] = Retweets
#Retweets.head()

# %%
#Reactions = stats.groupby(stats["Date"])["Reactions"].mean()
#stats_derived['Reactions'] = Reactions
#Reactions.head()

# %%
#Threads = stats.groupby(stats["Date"])["Threads"].mean()
#stats_derived['Threads'] = Threads
#Threads.head()

# %%
stats_derived.tail(5)
# Out:
#             Self_Congruence BrandLoyalty  BrandEquity       Reach       AVE  \
# date
# 2024-06-17         0.055131        0.475     0.279710  307.020833  2.839583
# 2024-06-18         0.158635     0.557143     0.234051  382.817204  3.540968
# 2024-06-19         0.163251       0.6875     0.063748  368.381443  3.408247
# 2024-06-20         0.033373     0.513514     0.003059  381.482456  3.529386
# 2024-06-21         0.137691          NaN     0.000000  417.886792  3.865472
#
#             TwitterAuthority  TwitterFollowers  TwitterFollowing
# date
# 2024-06-17          3.750000        307.020833        513.104167
# 2024-06-18          3.870968        382.817204        494.000000
# 2024-06-19          4.010309        368.381443        542.587629
# 2024-06-20          3.982456        381.482456        415.096491
# 2024-06-21          4.075472        417.886792        683.547170

# %% [markdown]
# Stock Market variable appended to dataset

# %%
stats_derived["Open"] = None

# %%
for i in range(len(stock)):
  for j in range(len(stats_derived)):
    if stock.Date[i] == stats_derived.index[j]:
      stats_derived["Open"][j] = stock.Open[i]

# %%
#Replace the "nones" with the previous price (Friday)
for i in range(len(stats_derived)):
  if stats_derived.Open[i] == None:
    stats_derived.Open[i] = stats_derived.Open[i-1]

# %%
stats_derived.head(5)
# Out:
#             Self_Congruence BrandLoyalty  BrandEquity       Reach       AVE  \
# date
# 2022-07-22         0.475651         0.74     0.634201  343.113208  3.173962
# 2022-07-23         0.446156     0.728477     0.604157  365.377907  3.380058
# 2022-07-24         0.431740     0.713235     0.596956  329.198718  3.044872
# 2022-07-25         0.425161          0.7     0.598819  348.558659  3.224078
# 2022-07-26         0.435984      0.72327     0.594574  336.728814  3.114802
#
#             TwitterAuthority  TwitterFollowers  TwitterFollowing    Open
# date
# 2022-07-22          3.735849        343.113208        539.490566  103.28
# 2022-07-23          3.837209        365.377907        596.186047  103.28
# 2022-07-24          3.724359        329.198718        506.788462  103.28
# 2022-07-25          3.770950        348.558659        543.910615  102.78
# 2022-07-26          3.644068        336.728814        545.960452  102.14

# %%
stats_derived.tail()
# Out:
#             Self_Congruence BrandLoyalty  BrandEquity       Reach       AVE  \
# date
# 2024-06-17         0.055131        0.475     0.279710  307.020833  2.839583
# 2024-06-18         0.158635     0.557143     0.234051  382.817204  3.540968
# 2024-06-19         0.163251       0.6875     0.063748  368.381443  3.408247
# 2024-06-20         0.033373     0.513514     0.003059  381.482456  3.529386
# 2024-06-21         0.137691          NaN     0.000000  417.886792  3.865472
#
#             TwitterAuthority  TwitterFollowers  TwitterFollowing    Open
# date
# 2024-06-17          3.750000        307.020833        513.104167  100.98
# 2024-06-18          3.870968        382.817204        494.000000  101.12
# 2024-06-19          4.010309        368.381443        542.587629  101.12
# 2024-06-20          3.982456        381.482456        415.096491  100.57
# 2024-06-21          4.075472        417.886792        683.547170  100.57

# %%
len(stats_derived)
# Out:
# 701

# %% [markdown]
# # **PCA**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
stats_derived = stats_derived.dropna()
stats_derived = stats_derived.reset_index(drop=True)

# %%
dataset = stats_derived
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
#Determine portion of the dataset that is to be the test set
len(stats_derived) - round(len(stats_derived)*.20)
# Out:
# 559

# %%
X_train = X[:519]
X_test = X[519:]
y_train = y[:519]
y_test = y[519:]

#X_train = X[:559]
#X_test = X[559:]
#y_train = y[:559]
#y_test = y[559:]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA
#pca = PCA(n_components = 5)
  #use the above code with 4 components to create elbow chart
  #with one component confirmed as relevant, re-run with code set to 1 component (below)
pca = PCA(n_components = 3)
#pca = PCA(n_components = 2)
dataset_train = pca.fit_transform(X_train)
dataset_test = pca.transform(X_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.59125428, 0.21783272, 0.12696845])

# %%
print(abs( pca.components_ ))
# Out:
# [[0.05487867 0.07000873 0.19363449 0.45148403 0.45147992 0.41456969
#   0.45148403 0.41378133]
#  [0.71949389 0.55778904 0.38272899 0.08280896 0.08285327 0.04319327
#   0.08280896 0.047681  ]
#  [0.12387359 0.63094093 0.71535685 0.02435298 0.02437464 0.21798044
#   0.02435298 0.15980528]]

# %%
stats_derived.columns
# Out:
# Index(['Self_Congruence', 'BrandLoyalty', 'BrandEquity', 'Reach', 'AVE',
#        'TwitterAuthority', 'TwitterFollowers', 'TwitterFollowing', 'Open'],
#       dtype='object')

# %%
#To be run with n=5 components in the previous code block
pca_df = pd.DataFrame(data = dataset_train, columns = ['PC 1', 'PC 2', 'PC 3'])
pca_df.head()
print(pca_df)
# Out:
#          PC 1      PC 2      PC 3
# 0   -1.205423  1.279749 -1.237574
# 1   -0.574856  0.991108 -1.190351
# 2   -1.408968  0.820399 -0.953968
# 3   -1.008501  0.784993 -1.073564
# 4   -1.292576  0.868717 -0.923109
# ..        ...       ...       ...
# 514 -0.290216 -1.464218  0.281479
# 515  0.801954 -1.033556 -0.775471
# 516 -1.148220 -1.097962  0.537906
# 517  0.485720 -0.545961 -0.641703
# 518  1.992286 -0.054653 -0.969801
#
# [519 rows x 3 columns]

# %%
#Confirming that only one principal component is providing value
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
#Combined x and y pred back into a single dataset with columns
y_train = pd.DataFrame(y_train)
dataset_train = pd.DataFrame(dataset_train)

# %%
y_test = pd.DataFrame(y_test)
dataset_test = pd.DataFrame(dataset_test)

# %%
dataset_train = pd.concat([dataset_train, y_train], axis=1)

# %%
dataset_test = pd.concat([dataset_test, y_test], axis=1)

# %%
dataset_test.head()
# Out:
#           0         1         2      0
# 0  1.566141 -0.466386 -0.869711  91.62
# 1 -0.030989 -0.581177  0.623682  91.62
# 2  0.105665 -0.734599  0.028874  90.84
# 3  0.234209 -1.029138 -0.209918  90.91
# 4 -0.641885 -0.220737 -0.398944  90.09

# %% [markdown]
# # **RNN Modelling**

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the training set

# %%
#transform into numpy array
#training_set = dataset_train.iloc[:,0:2].values
training_set = dataset_train.iloc[:,0:4].values
training_set
# Out:
# array([[-1.2054229379635388, 1.279749012477104, -1.2375735478277932,
#         103.28],
#        [-0.5748559461905823, 0.9911083323030117, -1.1903509688126888,
#         103.28],
#        [-1.4089677897190744, 0.8203986665403794, -0.9539680431188637,
#         103.28],
#        ...,
#        [-1.148220021112375, -1.0979620481096504, 0.537905865957473,
#         91.93],
#        [0.48572015835179916, -0.5459614569609674, -0.6417027117807791,
#         91.62],
#        [1.992286074676769, -0.05465306229329845, -0.9698012875136475,
#         91.62]], dtype=object)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1)) #feature range sets the normalization scale between 0 and 1
training_set = pd.DataFrame(training_set)
training_set.columns = training_set.columns.astype(str)
training_set = training_set.astype(float)
training_set_scaled = sc.fit_transform(training_set)
dataset_test = sc.transform(dataset_test)
  #added this to address problem of scale at the end.

# %% [markdown]
# Creating a data structure with 60 timesteps and 1 output

# %%
X_train = [] #input for the model
y_train = [] #output for the model (the predicted variable/value)
#for i in range(60, len(dataset_train)):
#for i in range(7, len(dataset_train)):
for i in range(30, len(dataset_train)):
    #X_train.append(training_set_scaled[i-7:i, 0:3])
    #X_train.append(training_set_scaled[i-60:i, 0:3])
    X_train.append(training_set_scaled[i-30:i, 0:3])
    y_train.append(training_set_scaled[i, -1])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# Reshaping

# %%
#This code creates a 3 dimensional shape that could allow for additional variables to be included in the model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 3))

  #X_train.shape[0]--this gives us the number of rows/lines
  #X_train.shape[1]--this gives us the number of columns
  #The '1' at the end of the code is the number of predictors

# %% [markdown]
# Importing the Keras libraries and packages

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow as tf

# %% [markdown]
# Initialising the RNN

# %%
regressor = Sequential()
#We are using regression to predict a continuous value

# %% [markdown]
# Adding the first LSTM layer and some Dropout regularisation

# %%
#regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 3)))
regressor.add(LSTM(units = 58, return_sequences = True, input_shape = (X_train.shape[1], 3)))
  #input 3 arguments into LSTM():
    # number of units is number of LSTM cells, or memory units or neurons
      #A large number of neurons increases the dimensionality
    # Return sequence indicates that there will be an LSTM layer added after this
    #input shape is the shape of the 3 dimensional array that was created in the "Reshaping" step
regressor.add(Dropout(0.1774505073513715))
  # This "Dropout regularization" is to prevent overfitting
  #This signifies that 20 percent of the neurons (in this case 10) will be dropped out of each iteration...
    #... of the training

# %% [markdown]
# Adding a second LSTM layer and some Dropout regularization

# %%
#regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(LSTM(units = 58, return_sequences = True))
  #Note: We do not have to add the input shape argument
regressor.add(Dropout(0.1774505073513715))

# %% [markdown]
# Adding a third LSTM layer and some Dropout regularisation

# %%
#regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(LSTM(units = 58, return_sequences = True))
regressor.add(Dropout(0.1774505073513715))

# %% [markdown]
# Adding a fourth LSTM layer and some Dropout regularisation

# %%
#regressor.add(LSTM(units = 50))
regressor.add(LSTM(units = 58))
  #Note that we don't need the 'return_sequences' argument because this is the last layer before...
    #...the output layer
regressor.add(Dropout(0.1774505073513715))

# %% [markdown]
# Adding the output layer

# %%
regressor.add(Dense(units = 1))
  #the units=1 indicates that there is only one dimension to the output layer

# %% [markdown]
# Compiling the RNN

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
#regressor.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
  #setting the model's optimizer and loss function...
    #...This adjusts the weights of the model
      #the "Adam optimizer" is short for "Adaptive Moment Estimation" and mimimizes the loss function
  #mean squared error is the loss funciton since we're doing a regression

# %%
#LOOK FOR: optuna: looks at all optimizers and chooses the best
  #https://towardsdatascience.com/state-of-the-art-machine-learning-hyperparameter-optimization-with-optuna-a315d8564de1

#The loss was reporting as loss:nan, possibly due to exploding gradients. Gradient clipping may be applied:
#from keras import optimizers

#optimizer = optimizers.Adam(clipvalue=0.5)
#regressor.compile(optimizer=optimizer, loss='mean_squared_error')

# %%
y_train = np.array(y_train, dtype=np.float32)
X_train = tf.convert_to_tensor(X_train)
y_train = tf.convert_to_tensor(y_train)

# %%
#Hyperparameter tuning
#https://docs.google.com/spreadsheets/d/1U_IKsR19jffpC8lj5JdokXuYtt7xFSkTSZ9KBhARnyg/edit?gid=0#gid=0

# %% [markdown]
# Fitting the RNN to the Training set

# %%
regressor.fit(X_train, y_train, epochs = 196, batch_size = 6)#baseline parameters: epoch = 100, batch_size = 32
  #first two arguments signify the model's inputs
  #epochs signifies number of iterations in the training
  #batches indicates that the prediction is made every 32 stock prices
# Out:
# Epoch 1/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0411
# Epoch 2/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0284
# Epoch 3/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0209
# Epoch 4/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0196
# Epoch 5/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0206
# Epoch 6/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0194
# Epoch 7/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0173
# Epoch 8/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0198
# Epoch 9/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0185
# Epoch 10/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0175
# Epoch 11/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0203
# Epoch 12/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0163
# Epoch 13/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0189
# Epoch 14/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193
# Epoch 15/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0169
# Epoch 16/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0182
# Epoch 17/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0176
# Epoch 18/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0179
# Epoch 19/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0165
# Epoch 20/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0169
# Epoch 21/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0155
# Epoch 22/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0175
# Epoch 23/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0196
# Epoch 24/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0188
# Epoch 25/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0164
# Epoch 26/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0192
# Epoch 27/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0178
# Epoch 28/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0155
# Epoch 29/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0158
# Epoch 30/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0154
# Epoch 31/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0168
# Epoch 32/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0161
# Epoch 33/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0158
# Epoch 34/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0161
# Epoch 35/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0148
# Epoch 36/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0144
# Epoch 37/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0158
# Epoch 38/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0146
# Epoch 39/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147
# Epoch 40/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0156
# Epoch 41/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0170
# Epoch 42/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0136
# Epoch 43/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0144
# Epoch 44/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0153
# Epoch 45/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0144
# Epoch 46/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0129
# Epoch 47/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0133
# Epoch 48/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0141
# Epoch 49/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0129
# Epoch 50/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0116
# Epoch 51/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0113
# Epoch 52/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110
# Epoch 53/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110
# Epoch 54/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0106
# Epoch 55/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0113
# Epoch 56/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080
# Epoch 57/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0089
# Epoch 58/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0097
# Epoch 59/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0106
# Epoch 60/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0105
# Epoch 61/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0091
# Epoch 62/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098
# Epoch 63/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080
# Epoch 64/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0095
# Epoch 65/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084
# Epoch 66/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0102
# Epoch 67/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082
# Epoch 68/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082
# Epoch 69/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0085
# Epoch 70/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0077
# Epoch 71/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0076
# Epoch 72/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0075
# Epoch 73/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066
# Epoch 74/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058
# Epoch 75/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066
# Epoch 76/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0133
# Epoch 77/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0065
# Epoch 78/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0065
# Epoch 79/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0060
# Epoch 80/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0056
# Epoch 81/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0079
# Epoch 82/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0066
# Epoch 83/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0047
# Epoch 84/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0087
# Epoch 85/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059
# Epoch 86/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0045
# Epoch 87/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0052
# Epoch 88/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0052
# Epoch 89/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0056
# Epoch 90/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0057
# Epoch 91/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0050
# Epoch 92/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035
# Epoch 93/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0039
# Epoch 94/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0075
# Epoch 95/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0047
# Epoch 96/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024
# Epoch 97/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022
# Epoch 98/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034
# Epoch 99/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082
# Epoch 100/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0038
# Epoch 101/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025
# Epoch 102/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023
# Epoch 103/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0061
# Epoch 104/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0042
# Epoch 105/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0051
# Epoch 106/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0091
# Epoch 107/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0059
# Epoch 108/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084
# Epoch 109/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0044
# Epoch 110/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022
# Epoch 111/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023
# Epoch 112/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021
# Epoch 113/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027
# Epoch 114/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021
# Epoch 115/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022
# Epoch 116/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 117/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0059
# Epoch 118/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0020
# Epoch 119/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024
# Epoch 120/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018
# Epoch 121/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020
# Epoch 122/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016
# Epoch 123/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016
# Epoch 124/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 125/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018
# Epoch 126/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 127/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 128/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 129/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017
# Epoch 130/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0018
# Epoch 131/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0063
# Epoch 132/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0068
# Epoch 133/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035
# Epoch 134/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020
# Epoch 135/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020
# Epoch 136/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 137/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 138/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016
# Epoch 139/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 140/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 141/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018
# Epoch 142/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017
# Epoch 143/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016
# Epoch 144/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0018
# Epoch 145/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0108
# Epoch 146/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0113
# Epoch 147/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0077
# Epoch 148/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0045
# Epoch 149/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0057
# Epoch 150/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0042
# Epoch 151/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0048
# Epoch 152/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0034
# Epoch 153/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027
# Epoch 154/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019
# Epoch 155/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0018
# Epoch 156/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047
# Epoch 157/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017
# Epoch 158/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017
# Epoch 159/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 160/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 161/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019
# Epoch 162/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025
# Epoch 163/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016
# Epoch 164/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 165/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0012
# Epoch 166/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014
# Epoch 167/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 168/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 169/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013
# Epoch 170/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 171/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016
# Epoch 172/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 173/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 174/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 175/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013
# Epoch 176/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 177/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0039
# Epoch 178/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0067
# Epoch 179/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0043
# Epoch 180/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021
# Epoch 181/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 182/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015
# Epoch 183/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 184/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017
# Epoch 185/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 186/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0012
# Epoch 187/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0012
# Epoch 188/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0011
# Epoch 189/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015
# Epoch 190/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 191/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012
# Epoch 192/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0015
# Epoch 193/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013
# Epoch 194/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.4214e-04
# Epoch 195/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014
# Epoch 196/196
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0010

# %% [markdown]
# RUNNING a SAVED MODEL

# %%
#save the model
#import pickle
#pickle.dump(regressor, open('regressor.pkl', 'wb'))
#from google.colab import files
#files.download('regressor.pkl')

# %%
#loading the previous trained model
#regressor_optimal = pickle.load(open('regressor.pkl', 'rb'))
#regressor_optimal

# %% [markdown]
# Making the predictions and visualising the results

# %% [markdown]
# Getting the real stock price

# %%
  #USE IF RUNNING NEW MODEL
real_stock_price = dataset_test[:, -1]
  #USE IF RUNNING THE SAVED OPTIMAL MODEL
#real_stock_price = dataset_test.iloc[:, -1]

# %%
real_stock_price
# Out:
# array([0.27438089, 0.27438089, 0.25728687, 0.25882095, 0.24085032,
#        0.24150778, 0.24150778, 0.24150778, 0.24150778, 0.24106947,
#        0.24391847, 0.28139382, 0.24786325, 0.24786325, 0.24786325,
#        0.27284681, 0.26188911, 0.23493316, 0.22550953, 0.23120754,
#        0.23120754, 0.23120754, 0.23120754, 0.2452334 , 0.29541968,
#        0.2533421 , 0.28972167, 0.28972167, 0.28972167, 0.30177515,
#        0.35787859, 0.33574403, 0.32478632, 0.34845496, 0.34845496,
#        0.34845496, 0.35765943, 0.38176638, 0.37957484, 0.37847907,
#        0.37650668, 0.37650668, 0.37650668, 0.38571115, 0.39053254,
#        0.40083279, 0.61319307, 0.6684199 , 0.6684199 , 0.6684199 ,
#        0.6307254 , 0.63949156, 0.689897  , 0.7008547 , 0.72145518,
#        0.72145518, 0.72145518, 0.72145518, 0.69581416, 0.64387464,
#        0.63313609, 0.62393162, 0.62393162, 0.62393162, 0.62283585,
#        0.62853386, 0.65044927, 0.70216963, 0.70874425, 0.70874425,
#        0.70874425, 0.7357002 , 0.75630068, 0.74468551, 0.69252685,
#        0.68113083, 0.68113083, 0.68113083, 0.67915845, 0.73241289,
#        0.73723428, 0.71531887, 0.71225071, 0.71225071, 0.71225071,
#        0.72737234, 0.7519176 , 0.77821609, 0.83037475, 0.82884067,
#        0.82884067, 0.82884067, 0.82993645, 0.88823143, 0.91737892,
#        0.92373439, 0.92373439, 0.92373439, 0.92373439, 0.94148586,
#        0.90116152, 0.9460881 , 0.87924611, 0.82182774, 0.82182774,
#        0.82182774, 0.85294762, 0.83892176, 0.82182774, 0.843524  ,
#        0.81722551, 0.81722551, 0.81722551, 0.78413325, 0.73898751,
#        0.76484769, 0.74687705, 0.71488056, 0.71488056, 0.71488056,
#        0.74512382, 0.73920666, 0.74600044, 0.70392286, 0.71772956,
#        0.71772956, 0.71772956, 0.7438089 , 0.7438089 , 0.70545694,
#        0.70852509, 0.7547666 , 0.7547666 , 0.7547666 , 0.78238001,
#        0.61691869, 0.56541749, 0.55928117, 0.60968661, 0.60968661,
#        0.60968661, 0.58053912, 0.57418365, 0.58119658, 0.52465483,
#        0.53758492, 0.53758492, 0.53758492, 0.5310103 , 0.52355906,
#        0.52333991, 0.52333991, 0.47666009, 0.47666009, 0.47666009,
#        0.47666009, 0.48783695, 0.49660311, 0.48301556, 0.49134341,
#        0.49134341, 0.49134341, 0.54941924, 0.5042735 , 0.52377822,
#        0.48104317, 0.47687925, 0.47687925, 0.47687925, 0.48542625,
#        0.51588867, 0.48433048, 0.47140039, 0.45386807, 0.45386807,
#        0.45386807, 0.47950909, 0.48257725, 0.48257725, 0.47052378])

# %%
dataset_train = dataset_train.reset_index(drop=True)
dataset_test = pd.DataFrame(dataset_test)
dataset_test = dataset_test.reset_index(drop=True)
dataset_test.columns = ["Predictor1", "Predictor2", "Predictor3", "Open"]
dataset_train.columns = ["Predictor1", "Predictor2", "Predictor3", "Open"]
dataset_train.head()
# Out:
#    Predictor1  Predictor2  Predictor3    Open
# 0   -1.205423    1.279749   -1.237574  103.28
# 1   -0.574856    0.991108   -1.190351  103.28
# 2   -1.408968    0.820399   -0.953968  103.28
# 3   -1.008501    0.784993   -1.073564  102.78
# 4   -1.292576    0.868717   -0.923109  102.14

# %%
dataset_test.head()
# Out:
#    Predictor1  Predictor2  Predictor3      Open
# 0    0.464667    0.429972    0.044705  0.274381
# 1    0.398981    0.418888    0.176040  0.274381
# 2    0.404601    0.404073    0.123730  0.257287
# 3    0.409888    0.375632    0.102730  0.258821
# 4    0.373856    0.453692    0.086106  0.240850

# %%
# Reset the indices of dataset_train and dataset_test
dataset_train = dataset_train.reset_index(drop=True)
dataset_test = dataset_test.reset_index(drop=True)

# Concatenate the DataFrames

dataset_total = pd.concat((dataset_train[['Predictor1', 'Predictor2', 'Predictor3']], dataset_test[['Predictor1', 'Predictor2', 'Predictor3']]), axis=0)


inputs = dataset_total[len(dataset_total) - len(dataset_test) - 30:].values
#inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
#inputs = dataset_total[len(dataset_total) - len(dataset_test) - 7:].values

inputs = inputs.reshape(-1, 3)


print(inputs.shape)
# Out:
# (210, 3)

# %%
from tensorflow.keras.utils import timeseries_dataset_from_array

# %% [markdown]
# Getting the predicted stock price

# %%
sc = StandardScaler(with_mean=False, with_std=False)
sc.fit(inputs)
inputs = sc.transform(inputs)
  #Scaling the inputs
X_test = []
#for i in range(7, len(inputs)):
for i in range(30, len(inputs)):
#for i in range(60, len(inputs)):
    #X_test.append(inputs[i-60:i, 0:3])
    X_test.append(inputs[i-30:i, 0:3])
    #X_test.append(inputs[i-7:i, 0:3])
X_test = np.array(X_test)
#X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test = tf.keras.utils.timeseries_dataset_from_array(
    data=inputs,
    targets=None,
    #sequence_length=60,  #Adjust if timesteps are adjusted
    sequence_length=30,
    #sequence_length=7,
    sampling_rate=1,
    batch_size=5,
    #batch_size=32,
)
  #To RUN A NEW MODEL
predicted_stock_price = regressor.predict(X_test)

  #TO RUN THE PREVIOUSLY SAVED OPTIMAL MODEL:
#predicted_stock_price = regressor_optimal.predict(X_test)

predicted_stock_price = predicted_stock_price.reshape(-1, 1)
  #reshape array with 1 column and as many rows as necessary to accommodate the data

#predicted_stock_price = sc.inverse_transform(inputs)[:,1]
#predicted_stock_price = sc.inverse_transform(predicted_stock_price)[:,0]
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
temp=[[predicted_stock_price], [real_stock_price]]
temp
# Out:
# [[array([[0.10937473],
#          [0.11447042],
#          [0.11784244],
#          [0.1177201 ],
#          [0.11510959],
#          [0.10212946],
#          [0.10305387],
#          [0.12200889],
#          [0.1346046 ],
#          [0.13831446],
#          [0.14363074],
#          [0.14471757],
#          [0.13267307],
#          [0.13429156],
#          [0.13881695],
#          [0.12938316],
#          [0.12046719],
#          [0.11194576],
#          [0.10045919],
#          [0.10107505],
#          [0.09762898],
#          [0.09641041],
#          [0.09283993],
#          [0.09656876],
#          [0.22867593],
#          [0.19142377],
#          [0.2612673 ],
#          [0.3859221 ],
#          [0.25174707],
#          [0.21412756],
#          [0.32721364],
#          [0.32783854],
#          [0.32848904],
#          [0.31987232],
#          [0.30692035],
#          [0.30413014],
#          [0.30223987],
#          [0.31257662],
#          [0.32444808],
#          [0.345029  ],
#          [0.37704703],
#          [0.41431525],
#          [0.43293613],
#          [0.3966022 ],
#          [0.3774579 ],
#          [0.36341783],
#          [0.35153005],
#          [0.34742182],
#          [0.34541848],
#          [0.341892  ],
#          [0.34109598],
#          [0.34172285],
#          [0.34318426],
#          [0.34759855],
#          [0.3689164 ],
#          [0.37279153],
#          [0.37432492],
#          [0.37474406],
#          [0.37544003],
#          [0.37182528],
#          [0.3759875 ],
#          [0.37119374],
#          [0.34996858],
#          [0.34826952],
#          [0.35309765],
#          [0.3542328 ],
#          [0.33880433],
#          [0.32929444],
#          [0.32490015],
#          [0.327904  ],
#          [0.34909588],
#          [0.38027793],
#          [0.39394444],
#          [0.4084671 ],
#          [0.4252891 ],
#          [0.44692078],
#          [0.43380827],
#          [0.42360508],
#          [0.41656202],
#          [0.40383673],
#          [0.39226955],
#          [0.3770582 ],
#          [0.3632661 ],
#          [0.35436025],
#          [0.35409114],
#          [0.34758806],
#          [0.35211867],
#          [0.36440867],
#          [0.36487663],
#          [0.37774354],
#          [0.40360594],
#          [0.37815654],
#          [0.34265918],
#          [0.2845223 ],
#          [0.25158867],
#          [0.22533098],
#          [0.2009739 ],
#          [0.18940383],
#          [0.18619272],
#          [0.19533274],
#          [0.1921154 ],
#          [0.23405585],
#          [0.2332235 ],
#          [0.23568952],
#          [0.24146743],
#          [0.24033323],
#          [0.24682081],
#          [0.25245768],
#          [0.25529286],
#          [0.26234868],
#          [0.28712627],
#          [0.3148285 ],
#          [0.33305275],
#          [0.35095805],
#          [0.36660048],
#          [0.3785381 ],
#          [0.3801314 ],
#          [0.3771751 ],
#          [0.3749315 ],
#          [0.37062982],
#          [0.36435658],
#          [0.36314487],
#          [0.3673436 ],
#          [0.37711865],
#          [0.385713  ],
#          [0.40409625],
#          [0.410734  ],
#          [0.39838284],
#          [0.39072776],
#          [0.3657974 ],
#          [0.3586234 ],
#          [0.36312717],
#          [0.3582577 ],
#          [0.35126728],
#          [0.34439322],
#          [0.33609277],
#          [0.3348522 ],
#          [0.34878427],
#          [0.3501569 ],
#          [0.34853056],
#          [0.33438504],
#          [0.36238995],
#          [0.35007334],
#          [0.33852687],
#          [0.33250868],
#          [0.3377138 ],
#          [0.328243  ],
#          [0.33227947],
#          [0.3233568 ],
#          [0.31475055],
#          [0.32256246],
#          [0.33950794],
#          [0.31324336],
#          [0.30522573],
#          [0.29092702],
#          [0.28223708],
#          [0.270621  ],
#          [0.2560136 ],
#          [0.24650404],
#          [0.23196332],
#          [0.22270997],
#          [0.21793234],
#          [0.21332498],
#          [0.20920613],
#          [0.20478842],
#          [0.19965625],
#          [0.19342548],
#          [0.18838899],
#          [0.18540107],
#          [0.18503667],
#          [0.18967783],
#          [0.19167803],
#          [0.20437226],
#          [0.19882213],
#          [0.20412366],
#          [0.2033473 ],
#          [0.2079959 ],
#          [0.19834319],
#          [0.1804813 ],
#          [0.14846364],
#          [0.11103418]], dtype=float32)],
#  [array([0.27438089, 0.27438089, 0.25728687, 0.25882095, 0.24085032,
#          0.24150778, 0.24150778, 0.24150778, 0.24150778, 0.24106947,
#          0.24391847, 0.28139382, 0.24786325, 0.24786325, 0.24786325,
#          0.27284681, 0.26188911, 0.23493316, 0.22550953, 0.23120754,
#          0.23120754, 0.23120754, 0.23120754, 0.2452334 , 0.29541968,
#          0.2533421 , 0.28972167, 0.28972167, 0.28972167, 0.30177515,
#          0.35787859, 0.33574403, 0.32478632, 0.34845496, 0.34845496,
#          0.34845496, 0.35765943, 0.38176638, 0.37957484, 0.37847907,
#          0.37650668, 0.37650668, 0.37650668, 0.38571115, 0.39053254,
#          0.40083279, 0.61319307, 0.6684199 , 0.6684199 , 0.6684199 ,
#          0.6307254 , 0.63949156, 0.689897  , 0.7008547 , 0.72145518,
#          0.72145518, 0.72145518, 0.72145518, 0.69581416, 0.64387464,
#          0.63313609, 0.62393162, 0.62393162, 0.62393162, 0.62283585,
#          0.62853386, 0.65044927, 0.70216963, 0.70874425, 0.70874425,
#          0.70874425, 0.7357002 , 0.75630068, 0.74468551, 0.69252685,
#          0.68113083, 0.68113083, 0.68113083, 0.67915845, 0.73241289,
#          0.73723428, 0.71531887, 0.71225071, 0.71225071, 0.71225071,
#          0.72737234, 0.7519176 , 0.77821609, 0.83037475, 0.82884067,
#          0.82884067, 0.82884067, 0.82993645, 0.88823143, 0.91737892,
#          0.92373439, 0.92373439, 0.92373439, 0.92373439, 0.94148586,
#          0.90116152, 0.9460881 , 0.87924611, 0.82182774, 0.82182774,
#          0.82182774, 0.85294762, 0.83892176, 0.82182774, 0.843524  ,
#          0.81722551, 0.81722551, 0.81722551, 0.78413325, 0.73898751,
#          0.76484769, 0.74687705, 0.71488056, 0.71488056, 0.71488056,
#          0.74512382, 0.73920666, 0.74600044, 0.70392286, 0.71772956,
#          0.71772956, 0.71772956, 0.7438089 , 0.7438089 , 0.70545694,
#          0.70852509, 0.7547666 , 0.7547666 , 0.7547666 , 0.78238001,
#          0.61691869, 0.56541749, 0.55928117, 0.60968661, 0.60968661,
#          0.60968661, 0.58053912, 0.57418365, 0.58119658, 0.52465483,
#          0.53758492, 0.53758492, 0.53758492, 0.5310103 , 0.52355906,
#          0.52333991, 0.52333991, 0.47666009, 0.47666009, 0.47666009,
#          0.47666009, 0.48783695, 0.49660311, 0.48301556, 0.49134341,
#          0.49134341, 0.49134341, 0.54941924, 0.5042735 , 0.52377822,
#          0.48104317, 0.47687925, 0.47687925, 0.47687925, 0.48542625,
#          0.51588867, 0.48433048, 0.47140039, 0.45386807, 0.45386807,
#          0.45386807, 0.47950909, 0.48257725, 0.48257725, 0.47052378])]]

# %% [markdown]
# Visualising the results

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Disney Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Disney Stock Price')
plt.title('Disney Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Disney Stock Price')
plt.legend()
plt.show()

# %%
scale = MinMaxScaler(feature_range = (0, 1))

predicted_stock_price_FULL = stats_derived['Open']
predicted_stock_price_FULL = predicted_stock_price_FULL.to_numpy() # Convert to NumPy array
predicted_stock_price_FULL = predicted_stock_price_FULL.reshape(-1, 1)
predicted_stock_price_FULL = pd.DataFrame(predicted_stock_price_FULL)
predicted_stock_price_FULL = scale.fit_transform(predicted_stock_price_FULL)

plt.plot(predicted_stock_price_FULL, color = 'red', label = 'Real Disney Stock Price')
plt.title('Disney Stock Price FULL TERM')
plt.xlabel('Time')
plt.ylabel('Disney Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# Model Evaluation: Using RMSE (Root Mean Squared Error)

# %%
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error
if len(real_stock_price) > len(predicted_stock_price):
    real_stock_price = real_stock_price[:len(predicted_stock_price)]
else:
    predicted_stock_price = predicted_stock_price[:len(real_stock_price)]
rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
mape = np.mean(np.abs((real_stock_price - predicted_stock_price) / real_stock_price)) * 100

# %%
#Goal: RMSE values between 0.2 and 0.5
print(f"MAE: {mae}, RMSE: {rmse}, MAPE: {mape}%")
# Out:
# MAE: 0.28700234929703505, RMSE: 0.33188674693212544, MAPE: 49.161724533464366%

# %% [markdown]
# Cross Correlation

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.correlate.html
predicted_stock_price_corr = np.array(predicted_stock_price).flatten()
real_stock_price_corr = np.array(real_stock_price).flatten()
correlated = np.correlate(predicted_stock_price_corr, real_stock_price_corr, "full") #alternate parameter: "full", "same", "valid"
correlated
#max_index = np.argmax(correlated)
#print(max_index)
# Out:
# array([ 0.05146341,  0.10664281,  0.16347025,  0.21994518,  0.27237023,
#         0.31851534,  0.36485286,  0.42204906,  0.48701064,  0.55777627,
#         0.62787666,  0.69699683,  0.75971708,  0.82268315,  0.88812902,
#         0.95480787,  1.01648906,  1.07893322,  1.12923819,  1.1794068 ,
#         1.22722812,  1.2736799 ,  1.32088521,  1.36977686,  1.4797678 ,
#         1.57308175,  1.69820001,  1.88156864,  2.00557694,  2.11094346,
#         2.26736252,  2.42534438,  2.58808658,  2.75153167,  2.90392078,
#         3.0556293 ,  3.21370303,  3.36890606,  3.53562399,  3.72711163,
#         3.92693449,  4.1527945 ,  4.37573936,  4.57863234,  4.77987313,
#         4.98324094,  5.18587396,  5.39482495,  5.59514419,  5.7904546 ,
#         5.97857499,  6.16849048,  6.37073972,  6.57218638,  6.78811759,
#         7.01442442,  7.23306279,  7.45297353,  7.67842569,  7.90062338,
#         8.12324123,  8.33968031,  8.54821424,  8.76920382,  8.98692712,
#         9.20316458,  9.42047075,  9.63568342,  9.85365332, 10.09205684,
#        10.34614954, 10.63268578, 10.93187283, 11.20674967, 11.49023743,
#        11.80444721, 12.10417276, 12.41239663, 12.73229491, 13.02598382,
#        13.31446919, 13.60535948, 13.8860792 , 14.16155065, 14.44360103,
#        14.7263157 , 15.01342795, 15.30631349, 15.59542182, 15.88500694,
#        16.19158746, 16.48353728, 16.75037507, 16.99797983, 17.22556995,
#        17.42309857, 17.61769143, 17.81598022, 18.00631459, 18.21577946,
#        18.41916632, 18.63354375, 18.85825552, 19.08563023, 19.33544996,
#        19.58256733, 19.82463034, 20.08343952, 20.34350918, 20.60021602,
#        20.86878142, 21.13865232, 21.41321354, 21.68175577, 21.9549223 ,
#        22.24611271, 22.53714519, 22.82320832, 23.11362051, 23.39637261,
#        23.68016507, 23.96301742, 24.2444433 , 24.52797375, 24.80446835,
#        25.07899119, 25.35721097, 25.61680508, 25.85723121, 26.09573354,
#        26.34332821, 26.58913147, 26.83401014, 27.06912913, 27.27265543,
#        27.4661244 , 27.65425864, 27.84726852, 28.03492318, 28.21183649,
#        28.37361742, 28.54695754, 28.71351151, 28.86536351, 29.01288494,
#        29.17271611, 29.34359904, 29.52065633, 29.70373854, 29.8828466 ,
#        30.05143157, 30.23396421, 30.40575914, 30.57493526, 30.73583237,
#        30.8902272 , 31.04671853, 31.18874664, 31.29303839, 31.3887616 ,
#        31.46211248, 31.50799892, 31.58461548, 31.65971163, 31.70473604,
#        31.73794076, 31.7633342 , 31.78559957, 31.81246242, 31.83400554,
#        31.85820477, 31.87977636, 31.90491352, 31.91527563, 31.90353128,
#        31.89043247, 31.88139113, 31.86982236, 31.86463196, 31.86802316,
#        31.75887816, 31.65230133, 31.55386837, 31.44309767, 31.33420555,
#        31.2361875 , 31.13893579, 31.03239748, 30.9137223 , 30.7961228 ,
#        30.68794086, 30.57420801, 30.46619317, 30.35626643, 30.2518776 ,
#        30.14882934, 30.04565675, 29.9305024 , 29.82100714, 29.69561286,
#        29.57197386, 29.44692663, 29.3203295 , 29.19138673, 29.01893648,
#        28.85181002, 28.65902614, 28.4266316 , 28.2270992 , 28.03472356,
#        27.81052486, 27.58309373, 27.35167438, 27.12273912, 26.89513396,
#        26.6678184 , 26.43460118, 26.20314931, 25.96464655, 25.72254993,
#        25.47290414, 25.21455032, 24.95702111, 24.69824092, 24.42209284,
#        24.12699493, 23.84596574, 23.57882325, 23.32292938, 23.0801069 ,
#        22.84339264, 22.60945256, 22.37723398, 22.14816105, 21.91113845,
#        21.66659402, 21.42408766, 21.17341958, 20.9227925 , 20.67259264,
#        20.4216304 , 20.17212565, 19.92813726, 19.6807866 , 19.42518864,
#        19.168405  , 18.90620749, 18.64465749, 18.38221522, 18.12025161,
#        17.85150418, 17.5755188 , 17.29686059, 17.0170639 , 16.73716274,
#        16.44686965, 16.15761938, 15.85693753, 15.54529123, 15.23454523,
#        14.9190519 , 14.61257191, 14.3145768 , 14.02405238, 13.73309891,
#        13.4457119 , 13.16427757, 12.88996789, 12.61707813, 12.34164607,
#        12.05789033, 11.78113042, 11.52374919, 11.28692522, 11.06551209,
#        10.84738792, 10.63826667, 10.43630406, 10.2354794 , 10.02924858,
#         9.828957  ,  9.62466242,  9.42169521,  9.22021163,  9.0117447 ,
#         8.79963221,  8.58692412,  8.37505807,  8.16983558,  7.97107109,
#         7.7713696 ,  7.56836086,  7.36766771,  7.17589734,  6.98637368,
#         6.79417049,  6.60580012,  6.41688421,  6.22906215,  6.04386692,
#         5.85970244,  5.66781667,  5.47399328,  5.27816831,  5.08113403,
#         4.88019669,  4.6798301 ,  4.48538498,  4.30045458,  4.12515125,
#         3.94572959,  3.76880433,  3.59935703,  3.44940329,  3.3339894 ,
#         3.22321241,  3.1130536 ,  3.0015521 ,  2.89001398,  2.77932164,
#         2.67052554,  2.55487083,  2.4421336 ,  2.33707085,  2.23485776,
#         2.13172665,  2.0308789 ,  1.9327535 ,  1.83455001,  1.73806   ,
#         1.64700653,  1.55337494,  1.46667372,  1.3827633 ,  1.30778363,
#         1.23055132,  1.16420071,  1.10346575,  1.0455593 ,  0.99138487,
#         0.93976248,  0.88847457,  0.83640829,  0.78119553,  0.72638319,
#         0.67610373,  0.62731469,  0.57954715,  0.52917595,  0.48446334,
#         0.43920751,  0.39321778,  0.34392669,  0.29597633,  0.24636567,
#         0.19635265,  0.14213994,  0.0902562 ,  0.04073558])

# %%
np.corrcoef( predicted_stock_price_corr, real_stock_price_corr )[0,1]
# Out:
# 0.5458003391381836

# %%
f, axarr = plt.subplots(2, sharex=True)

axarr[0].plot(predicted_stock_price)
axarr[0].plot(real_stock_price)
axarr[0].grid(True)

autocorrelation1 = np.correlate(predicted_stock_price.flatten(),
                                predicted_stock_price.flatten(),
                                'same')[round(len(predicted_stock_price)/2):]
autocorrelation2 = np.correlate(real_stock_price.flatten(),
                                real_stock_price.flatten(),
                                'same')[round(len(predicted_stock_price)/2):]
axarr[1].plot(autocorrelation1)
axarr[1].plot(autocorrelation2)
axarr[1].grid(True)

plt.show()

# %% [markdown]
# Cross Correlation Using scipy

# %%
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.correlate.html#scipy.signal.correlate
from scipy import signal
#import matplotlib.pyplot as plt
rng = np.random.default_rng()

# %%
#LOOK INTO THE SHIFT--is it forward or backwards
corr = signal.correlate(predicted_stock_price_corr, real_stock_price_corr, mode='full')
lags = signal.correlation_lags(len(predicted_stock_price_corr), len(real_stock_price_corr))
corr /= np.max(corr)

# %%
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, figsize=(4.8, 4.8))
ax_orig.plot(predicted_stock_price_corr)
ax_orig.set_title('Predicted Stock Price')
ax_orig.set_xlabel('Date')
ax_noise.plot(real_stock_price_corr)
ax_noise.set_title('Actual Stock Price')
ax_noise.set_xlabel('Date')
ax_corr.plot(lags, corr) # Now 'lags' and 'corr' have the same length
ax_corr.set_title('Cross-correlated relationship')
ax_corr.set_xlabel('Lag')
ax_orig.margins(0, 0.1)
ax_noise.margins(0, 0.1)
ax_corr.margins(0, 0.1)
fig.tight_layout()
plt.show()

# %%
corr = signal.correlate(predicted_stock_price_corr, real_stock_price_corr, mode='same')

# %%
clock = np.arange(64, len(predicted_stock_price_corr), len(predicted_stock_price_corr))
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, sharex=True)
ax_orig.plot(predicted_stock_price_corr)
ax_orig.plot(clock, predicted_stock_price_corr[clock], 'ro')
ax_orig.set_title('Predicted Stock Price')
ax_noise.plot(real_stock_price_corr)
ax_noise.set_title('Real Stock Price')
ax_corr.plot(corr)
ax_corr.plot(clock, corr[clock], 'ro')
ax_corr.axhline(0.5, ls=':')
ax_corr.set_title('Cross-correlated')
ax_orig.margins(0, 0.1)
fig.tight_layout()
plt.show()

# %% [markdown]
# TIME SHIFT

# %%
predicted_stock_price_shift = predicted_stock_price[:132]
real_stock_price_shift = real_stock_price[48:]

# %%
len(predicted_stock_price_shift)
# Out:
# 132

# %%
#predicted_stock_price_shift = predicted_stock_price[:110]
#real_stock_price_shift = real_stock_price[:110]

# %%
plt.plot(real_stock_price_shift, color = 'red', label = 'Real Disney Stock Price')
plt.plot(predicted_stock_price_shift, color = 'blue', label = 'Shifted Predicted Disney Stock Price')
plt.title('Shifted Disney Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Disney Stock Price')
plt.legend()
plt.show()

# %%
f, axarr = plt.subplots(2, sharex=True)

axarr[0].plot(predicted_stock_price_shift)
axarr[0].plot(real_stock_price_shift)
axarr[0].grid(True)

autocorrelation1 = np.correlate(predicted_stock_price_shift.flatten(),
                                predicted_stock_price_shift.flatten(),
                                'same')[round(len(predicted_stock_price_shift)/2):]
autocorrelation2 = np.correlate(real_stock_price_shift.flatten(),
                                real_stock_price_shift.flatten(),
                                'same')[round(len(predicted_stock_price_shift)/2):]
axarr[1].plot(autocorrelation1)
axarr[1].plot(autocorrelation2)
axarr[1].grid(True)

plt.show()

# %%
shift_rmse = math.sqrt(mean_squared_error(real_stock_price_shift, predicted_stock_price_shift))
shift_mae = mean_absolute_error(real_stock_price, predicted_stock_price)
shift_mape = np.mean(np.abs((real_stock_price - predicted_stock_price_shift) / real_stock_price)) * 100

# %%
print(f"MAE: {mae}, RMSE: {rmse}, MAPE: {mape}%")
# Out:
# MAE: 0.28700234929703505, RMSE: 0.33188674693212544, MAPE: 49.161724533464366%

# %%
print(f"shift_MAE: {shift_mae}, shift_RMSE: {shift_rmse}, shift_MAPE: {shift_mape}%")
# Out:
# shift_MAE: 0.28700234929703505, shift_RMSE: 0.4057300875702297, shift_MAPE: 48.89638558005577%

# %%
print(f"MAE: {shift_mae - mae}, RMSE: {shift_rmse - rmse}, MAPE: {shift_mape - mape}%")
# Out:
# MAE: 0.0, RMSE: 0.07384334063810427, MAPE: -0.2653389534085946%

# %%
#Correlation Coefficient:
predicted_stock_price_corr = np.array(predicted_stock_price_shift).flatten()
real_stock_price_corr = np.array(real_stock_price_shift).flatten()
correlated = np.correlate(predicted_stock_price_corr, real_stock_price_corr, "full")

# %%
np.corrcoef( predicted_stock_price_corr, real_stock_price_corr )[0,1]
# Out:
# 0.13495692516744506
